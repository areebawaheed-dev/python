# %% [markdown]
# <a href="https://colab.research.google.com/github/areebawaheed-dev/python/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a repel capable of performing addition , subtraction , multiplication and division operations on two numbers your program should format the output in readable manner

# %%
a=int(input("a=",))
b=float(input("b=",))
print(a+b)
print(a-b)
print(a/b)
print(a//b)
# Out:
# a=10
# b=2
# 12.0
# 8.0
# 5.0
# 5.0
